# %% [markdown]
# # Análise Explorátoria - Classificação de Filmes IMBd

# %% [markdown]
# Este projeto consiste em analisar as bases de dados de classificação de filmes da IMBb e TMBd com a linguagem de programação Python e suas principais bibliotecas para análise de dados.
# Todos os dados utilizados no projeto podem ser encontrados [aqui](https://github.com/rafaelladuarte/film_rating_exploratory_analysis/tree/main/Dados).

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Primiero vamos tratar e analisar conhecida a classificação de filmes da IMBd, também conhecida como Internet Movie Database, é uma base de dados online de informação sobre cinema TV, música e games, hoje pertencente à Amazon.

# %% [markdown]
# ##  IMBd

# %% [markdown]
# ### Tratamento

# %%
path_imbd_rating = "https://raw.githubusercontent.com/rafaelladuarte/film_rating_exploratory_analysis/main/Dados/ratings.csv"
path_imbd_movie = "https://raw.githubusercontent.com/rafaelladuarte/film_rating_exploratory_analysis/main/Dados/movies.csv"

# %%
df_imbd_rating = pd.read_csv(path_imbd_rating)
df_imbd_rating.sample(3)
# Out:
#        userId  movieId  rating   timestamp
# 71427     459    72998     5.0  1520233439
# 98126     606     6100     4.0  1171365536
# 11128      68     6893     3.5  1158534072

# %%
df_imbd_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
df_imbd_movie = pd.read_csv(path_imbd_movie)
df_imbd_movie.sample(3)
# Out:
#       movieId                        title              genres
# 5395     8998  That's Entertainment (1974)         Documentary
# 6077    41571   Memoirs of a Geisha (2005)       Drama|Romance
# 4282     6251    Piglet's Big Movie (2003)  Animation|Children

# %%
df_imbd_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9742 entries, 0 to 9741
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  9742 non-null   int64
#  1   title    9742 non-null   object
#  2   genres   9742 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 228.5+ KB

# %%
df_imbd_rating_mean = df_imbd_rating.groupby("movieId").mean()
df_imbd_rating_mean.sample(5)
# Out:
#          userId    rating     timestamp
# movieId
# 113849   599.00  2.500000  1.498531e+09
# 26158    318.00  4.000000  1.450043e+09
# 96430    443.00  5.000000  1.501723e+09
# 7458     323.25  3.427083  1.324687e+09
# 42004    413.50  3.500000  1.263312e+09

# %%
df_imbd = pd.merge(df_imbd_rating_mean, df_imbd_movie, how = 'inner', on = 'movieId')
df_imbd.sample(3)
# Out:
#       movieId      userId    rating     timestamp                     title  \
# 2533     3396  327.969697  3.590909  1.113670e+09  Muppet Movie, The (1979)
# 7336    78467  327.500000  1.875000  1.349422e+09          Jonah Hex (2010)
# 1369     1875  399.000000  3.916667  1.011581e+09      Clockwatchers (1997)
#
#                                  genres
# 2533  Adventure|Children|Comedy|Musical
# 7336      Action|Drama|Thriller|Western
# 1369                             Comedy

# %%
df_imbd["title"].str.extract(r'(\d{4})',expand=True)
# Out:
#          0
# 0     1995
# 1     1995
# 2     1995
# 3     1995
# 4     1995
# ...    ...
# 9719  2017
# 9720  2017
# 9721  2017
# 9722  2018
# 9723  1991
#
# [9724 rows x 1 columns]

# %%
df_imbd["year"]= df_imbd["title"].str.extract(r'(\d{4})',expand=True)
df_imbd.sample(5)
# Out:
#       movieId      userId   rating     timestamp  \
# 929      1230  329.275862  3.87069  1.173918e+09
# 8851   133802  464.000000  4.25000  1.465616e+09
# 6747    59915  610.000000  3.50000  1.493849e+09
# 8369   109850  419.500000  3.75000  1.460078e+09
# 7159    72167  202.000000  3.37500  1.427900e+09
#
#                                                title  \
# 929                                Annie Hall (1977)
# 8851                                Slow West (2015)
# 6747                                    Stuck (2007)
# 8369                           Need for Speed (2014)
# 7159  Boondock Saints II: All Saints Day, The (2009)
#
#                            genres  year
# 929                Comedy|Romance  1977
# 8851      Action|Thriller|Western  2015
# 6747              Horror|Thriller  2007
# 8369      Action|Crime|Drama|IMAX  2014
# 7159  Action|Crime|Drama|Thriller  2009

# %%
df_imbd["year"].unique()
# Out:
# array(['1995', '1994', '1996', '1976', '1992', '1967', '1993', '1964',
#        '1977', '1965', '1982', '1990', '1991', '1989', '1937', '1940',
#        '1969', '1981', '1973', '1970', '1955', '1959', '3000', '1968',
#        '1988', '1997', '1972', '1943', '1952', '1951', '1957', '1961',
#        '1958', '1954', '1934', '1944', '1960', '1963', '1942', '1941',
#        '1953', '1939', '1950', '2001', '1946', '1945', '1938', '1947',
#        '1935', '1936', '1956', '1949', '1932', '1975', '1974', '1971',
#        '1979', '1987', '1986', '1980', '1978', '1985', '1966', '1962',
#        '1983', '1984', '1948', '1933', '1931', '1922', '1600', '1998',
#        '2000', '1929', '1930', '1927', '1928', '2010', '1999', '1900',
#        '1926', '1919', '1921', '1925', '1923', '2002', '1776', '2003',
#        '1000', '1138', '1920', '1915', '1924', '2004', '1916', '1917',
#        '1492', '2046', '2005', '2006', '1902', nan, '1903', '2007',
#        '1408', '2008', '2009', '2012', '2011', '2013', '2014', '2015',
#        '2016', '2017', '2018', '1908', '2049', '2048'], dtype=object)

# %%
df_imbd["title"].str.extract(r'^([\w\s]+)',expand=True)
# Out:
#                                  0
# 0                       Toy Story
# 1                         Jumanji
# 2                Grumpier Old Men
# 3               Waiting to Exhale
# 4     Father of the Bride Part II
# ...                            ...
# 9719                  Black Butler
# 9720               No Game No Life
# 9721                        Flint
# 9722              Bungo Stray Dogs
# 9723              Andrew Dice Clay
#
# [9724 rows x 1 columns]

# %%
df_imbd["title1"] = df_imbd["title"].str.extract(r'^([\w\s]+)',expand=True)
df_imbd.sample(3)
# Out:
#       movieId      userId    rating     timestamp  \
# 9667   183959  111.000000  4.500000  1.517441e+09
# 7306    77455  267.769231  4.038462  1.398037e+09
# 398       457  319.452632  3.992105  1.031999e+09
#
#                                   title              genres  year  \
# 9667     Tom Segura: Disgraceful (2018)              Comedy  2018
# 7306  Exit Through the Gift Shop (2010)  Comedy|Documentary  2010
# 398                Fugitive, The (1993)            Thriller  1993
#
#                            title1
# 9667                   Tom Segura
# 7306  Exit Through the Gift Shop
# 398                      Fugitive

# %%
df_imbd["genres"].str.split(pat="|",expand = True)[0]
# Out:
# 0       Adventure
# 1       Adventure
# 2          Comedy
# 3          Comedy
# 4          Comedy
#           ...
# 9719       Action
# 9720    Animation
# 9721        Drama
# 9722       Action
# 9723       Comedy
# Name: 0, Length: 9724, dtype: object

# %%
df_imbd["main_genre"] = df_imbd["genres"].str.split(pat="|",expand = True)[0]
df_imbd.sample(3)
# Out:
#       movieId      userId    rating     timestamp  \
# 4508     6688  182.000000  3.500000  1.077070e+09
# 1729     2324  320.784091  4.147727  1.256650e+09
# 8802   131130   89.000000  5.000000  1.520409e+09
#
#                                            title                    genres  \
# 4508            Autumn Spring (Babí léto) (2001)              Comedy|Drama
# 1729  Life Is Beautiful (La Vita è bella) (1997)  Comedy|Drama|Romance|War
# 8802     Tom and Jerry: A Nutcracker Tale (2007)          Animation|Comedy
#
#       year              title1 main_genre
# 4508  2001      Autumn Spring      Comedy
# 1729  1997  Life Is Beautiful      Comedy
# 8802  2007       Tom and Jerry  Animation

# %%
df_imbd = df_imbd.drop(columns=['movieId','userId','title','genres'])
df_imbd.sample(3)
# Out:
#       rating     timestamp  year             title1 main_genre
# 7240    2.25  1.359060e+09  2010            Wolfman     Horror
# 7899    5.00  1.446573e+09  2008            Presto   Animation
# 6186    1.50  1.180828e+09  2005  American Haunting      Drama

# %%
df_imbd.rename(columns = {'title1':'title'}, inplace = True)

# %% [markdown]
# ### Análise

# %% [markdown]
# Algumas perguntas a se pensar:
#
# * Quais são os 3 melhores filmes e os 3 piores filmes?
# * Quantos filmes cada gênero tem? Qual genero tem mais filmes e qual tem menos?
# * Qual a média de nota dos filmes por gênero? Qual o gênero tem as melhores notas e qual tem as piores?
# * Qual a média de duração dos filmes por gênero? Qual o filme mais longo e o filme mais curto?
# * Qual a quantidade de filmes por decadas?

# %%
df_imbd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9724 entries, 0 to 9723
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rating      9724 non-null   float64
#  1   timestamp   9724 non-null   float64
#  2   year        9712 non-null   object
#  3   title       9708 non-null   object
#  4   main_genre  9724 non-null   object
# dtypes: float64(2), object(3)
# memory usage: 455.8+ KB

# %%
df_imbd.describe()
# Out:
#             rating     timestamp
# count  9724.000000  9.724000e+03
# mean      3.262448  1.260107e+09
# std       0.869874  1.830337e+08
# min       0.500000  8.297609e+08
# 25%       2.800000  1.108975e+09
# 50%       3.416667  1.240114e+09
# 75%       3.911765  1.445816e+09
# max       5.000000  1.537632e+09

# %%
df_imbd.sort_values('rating').head(3)
# Out:
#       rating     timestamp  year       title main_genre
# 5541     0.5  1.498503e+09  1990  Lionheart      Action
# 2685     0.5  1.520409e+09  1962      Gypsy     Musical
# 4872     0.5  1.331421e+09  1966   Follow Me     Comedy

# %%
df_imbd.sort_values('rating').tail(3)
# Out:
#       rating     timestamp  year           title main_genre
# 5862     5.0  1.161955e+09  2004    Palindromes   Adventure
# 7960     5.0  1.520409e+09  1995  Runaway Brain   Animation
# 6482     5.0  1.520409e+09  1999      Sun Alley      Comedy

# %%
df_imbd_genre = df_imbd["main_genre"].value_counts().to_frame().reset_index()
df_imbd_genre.rename(columns = {"index":"main_genre","main_genre":"count"}, inplace = True)
df_imbd_genre
# Out:
#             main_genre  count
# 0               Comedy   2776
# 1                Drama   2218
# 2               Action   1828
# 3            Adventure    652
# 4                Crime    534
# 5               Horror    468
# 6          Documentary    385
# 7            Animation    297
# 8             Children    197
# 9             Thriller     83
# 10              Sci-Fi     62
# 11             Mystery     48
# 12             Fantasy     42
# 13             Romance     38
# 14  (no genres listed)     34
# 15             Western     23
# 16             Musical     23
# 17           Film-Noir     12
# 18                 War      4

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax = sns.barplot(
    x=df_imbd_genre["main_genre"], 
    y=df_imbd_genre["count"], 
    data=df_imbd_genre,
    color="salmon",
    saturation=.5,
)
plt.xticks(rotation=45)
ax.set_title("Amount of Movies for Genres",fontsize= 'x-large')
ax.set_xlabel('Movie Genres',fontsize= 'x-large')
ax.set_ylabel('Amount of Movies',fontsize= 'x-large');
fig.savefig('images/imbd_amount_movies_genres.jpg')

# %%
fig, ax = plt.subplots(figsize=(15, 8))
plt.xticks(rotation=45)
ax = sns.boxplot(
    x=df_imbd["main_genre"], 
    y=df_imbd["rating"], 
    data=df_imbd,
    color="seagreen",
    saturation=.5
)
ax.set_title("Rating of Movies for Genres",fontsize= 'x-large')
ax.set_xlabel('Movie Genres',fontsize= 'x-large')
ax.set_ylabel('Rating of Movies',fontsize= 'x-large');
fig.savefig('images/imbd_rating_movies_genres.jpg')

# %%
df_imbd_rating = df_imbd.groupby("main_genre").mean().reset_index()[["main_genre","rating"]].sort_values("rating")
df_imbd_rating
# Out:
#             main_genre    rating
# 11              Horror  2.793645
# 4             Children  2.827037
# 16            Thriller  3.007170
# 15              Sci-Fi  3.066959
# 1               Action  3.094498
# 13             Mystery  3.148153
# 9              Fantasy  3.179774
# 5               Comedy  3.193691
# 14             Romance  3.205294
# 12             Musical  3.276389
# 2            Adventure  3.285179
# 0   (no genres listed)  3.371148
# 6                Crime  3.412260
# 8                Drama  3.460915
# 18             Western  3.471587
# 17                 War  3.525000
# 3            Animation  3.574865
# 7          Documentary  3.788913
# 10           Film-Noir  3.856218

# %%
df_imbd_rating_mean = df_imbd.groupby("title").mean().rating
df_imbd_rating_mean.sample(3)
# Out:
# title
# Be Cool              2.437500
# Rumor Has It         2.833333
# Night to Remember    3.000000
# Name: rating, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax = sns.histplot(
    data=df_imbd,
    x="rating", 
    color="purple",
    bins=15,
    kde=True
)
ax.set_title("Histogram Rating of Movies",fontsize= 'x-large')
ax.set_xlabel('Rating',fontsize= 'x-large')
ax.set_ylabel('Frequency',fontsize= 'x-large');
fig.savefig('images/imbd_hist_movies_rating.jpg')

# %%
year = df_imbd["year"].dropna()

# %%
decada = year.str.split(pat="",expand = True)
decada[4] = '0'
decada["decada"] = decada[1] + decada[2] + decada[3] + decada[4]

# %%
df_imbd_year = pd.merge(year, decada["decada"], right_index= True, left_index= True)
df_imbd_year
# Out:
#       year decada
# 0     1995   1990
# 1     1995   1990
# 2     1995   1990
# 3     1995   1990
# 4     1995   1990
# ...    ...    ...
# 9719  2017   2010
# 9720  2017   2010
# 9721  2017   2010
# 9722  2018   2010
# 9723  1991   1990
#
# [9712 rows x 2 columns]

# %%
df_imbd_year = df_imbd_year.astype(str).astype(int)
df_imbd_year = df_imbd_year[df_imbd_year["year"] > 1970]
df_imbd_year = df_imbd_year[df_imbd_year["year"] < 2018]
df_imbd_year
# Out:
#       year  decada
# 0     1995    1990
# 1     1995    1990
# 2     1995    1990
# 3     1995    1990
# 4     1995    1990
# ...    ...     ...
# 9718  2015    2010
# 9719  2017    2010
# 9720  2017    2010
# 9721  2017    2010
# 9723  1991    1990
#
# [8572 rows x 2 columns]

# %%
df_imbd_year["year"].value_counts().to_frame().reset_index()
# Out:
#     index  year
# 0    2002   310
# 1    2006   296
# 2    2001   295
# 3    2000   290
# 4    2007   283
# 5    2009   281
# 6    2003   278
# 7    2014   278
# 8    2004   276
# 9    1996   275
# 10   2015   274
# 11   2005   272
# 12   2008   269
# 13   1995   259
# 14   1999   259
# 15   1997   259
# 16   1998   256
# 17   2011   253
# 18   2010   248
# 19   2013   238
# 20   1994   237
# 21   2012   235
# 22   2016   218
# 23   1993   198
# 24   1992   165
# 25   1988   164
# 26   1987   152
# 27   1990   147
# 28   1991   146
# 29   2017   144
# 30   1989   141
# 31   1986   139
# 32   1985   127
# 33   1984    99
# 34   1981    91
# 35   1980    89
# 36   1982    87
# 37   1983    83
# 38   1979    68
# 39   1977    63
# 40   1973    59
# 41   1978    59
# 42   1971    46
# 43   1974    43
# 44   1976    42
# 45   1975    42
# 46   1972    39

# %%
df_imbd_decada = df_imbd_year["decada"].value_counts().to_frame().reset_index()
df_imbd_decada = df_imbd_decada.rename(columns={"index":"decada","decada":"count"})
df_imbd_decada
# Out:
#    decada  count
# 0    2000   2850
# 1    1990   2201
# 2    2010   1888
# 3    1980   1172
# 4    1970    461

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.barplot(
    x=df_imbd_decada["decada"], 
    y=df_imbd_decada["count"], 
    data=df_imbd_decada,
    color="yellow",
    saturation=.5,
)
ax.set_title("Amount of Movies for Decade",fontsize= 'x-large')
ax.set_xlabel('Decade',fontsize= 'x-large')
ax.set_ylabel('Amount of Decade',fontsize= 'x-large');
fig.savefig('images/imbd_amount_movies_decade.jpg')

# %%
total = df_imbd_decada["count"].sum()
total
# Out:
# 8572

# %%
df_imbd_decada['percent']= (df_imbd_decada["count"]/total)*100
df_imbd_decada = df_imbd_decada.round(2)
df_imbd_decada
# Out:
#    decada  count  percent
# 0    2000   2850    33.25
# 1    1990   2201    25.68
# 2    2010   1888    22.03
# 3    1980   1172    13.67
# 4    1970    461     5.38

# %%
fig, ax = plt.subplots(figsize=(10, 5))
plt.pie(
    df_imbd_decada["percent"], 
    labels = df_imbd_decada["decada"], 
    colors = sns.color_palette('pastel')[0:5], 
    autopct='%.0f%%'
)
plt.title("Movies for Decade",fontsize= 'x-large')
fig.savefig('images/imbd_amount_movies_decade.jpg')
